# %%
import tensorflow as tf
import numpy as np
from PIL import Image

# Define the path to the pretrained model
def detect_age(image):
    model_path = 'output/age_model_acc_0.815.h5'

    # Load the pretrained model
    model = tf.keras.models.load_model(model_path)

    # Open the image
    image = Image.open(image)

    # Resize the image
    image = image.resize((200, 200))
    image = image.convert('L')

    # Preprocess the image (if required)
    # ...
    img_array = np.array(image)

    # Add batch dimension
    img_array = np.expand_dims(img_array, axis=0)

    # If necessary, convert grayscale to RGB
    if img_array.shape[-1] == 1:
        img_array = np.repeat(img_array, 3, axis=-1)
        
    # Make predictions on the image
    predictions = model.predict(img_array)

    # Print the predictions
    print(predictions)

    def return_age_group(index):

        if index == 0:
            return '1-2'
        elif index == 1:
            return '3-9'
        elif index == 2:
            return '10-20'
        elif index == 3:
            return '21-25'
        elif index == 4:
            return '26-35'
        elif index == 5:
            return '36-45'
        elif index == 6:
            return '46-65'
        else:
            return '66-116'


    max_index = np.argmax(predictions)
    return return_age_group(max_index)

# %%
import cv2
import time

# Load pre-trained face detection model
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Initialize video capture
cap = cv2.VideoCapture(0)

while True:
    # Read frame from camera
    ret, frame = cap.read()

    # Convert frame to grayscale for face detection
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    if len(faces) == 0:
        # No face detected
        cv2.putText(frame, "No face detected", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)
    else:
        # Face detected
        for (x, y, w, h) in faces:
            # Draw rectangle around the face
            cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)

            #Capture a frame every 3 seconds
            if time.time() % 3 < 0.1:
                # Crop the face region
                face_roi = frame[y:y+h, x:x+w]
                
                # Call age detection function
                age = detect_age(face_roi)

            # Display age prediction
            cv2.putText(frame, f"Age: {21-25}", (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)

    # Display the frame
    cv2.imshow('Camera', frame)

    # Exit loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release video capture and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\Amit\AppData\Local\Programs\Python\Python311\Lib\site-packages\PIL\Image.py:3231, in open(fp, mode, formats)
#    3230 try:
# -> 3231     fp.seek(0)
#    3232 except (AttributeError, io.UnsupportedOperation):
#
# AttributeError: 'numpy.ndarray' object has no attribute 'seek'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 35
#      32     face_roi = frame[y:y+h, x:x+w]
#      34     # Call age detection function
# ---> 35     age = detect_age(face_roi)
#      37 # Display age prediction
#      38 cv2.putText(frame, f"Age: {21-25}", (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
#
# Cell In[1], line 13, in detect_age(image)
#      10 model = tf.keras.models.load_model(model_path)
#      12 # Open the image
# ---> 13 image = Image.open(image)
#      15 # Resize the image
#      16 image = image.resize((200, 200))
#
# File c:\Users\Amit\AppData\Local\Programs\Python\Python311\Lib\site-packages\PIL\Image.py:3233, in open(fp, mode, formats)
#    3231     fp.seek(0)
#    3232 except (AttributeError, io.UnsupportedOperation):
# -> 3233     fp = io.BytesIO(fp.read())
#    3234     exclusive_fp = True
#    3236 prefix = fp.read(16)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'read'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
